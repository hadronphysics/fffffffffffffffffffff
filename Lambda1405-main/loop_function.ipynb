# %%
using Plots

# %%
include("./src/loop_fun.jl")
include("./src/latt_para.jl")
# Out:
# lattice_params! (generic function with 1 method)

# %%
latt_para = lattice_params!()
mch = latt_para[:mch]
L = latt_para[:L]
# Out:
# 0.02052430944820622

# %%
Gmat!(1450, mch, [-1.6, -2.2], L, [0, 0, 0])
# Out:
# 8×8 Matrix{Float64}:
#  -663.771      0.0       39.7363  …     0.0       39.7363     0.0
#     0.0     -567.542      0.0          24.8125     0.0       24.8125
#    39.7363     0.0     -436.493         0.0       39.7363     0.0
#     0.0       24.8125     0.0          24.8125     0.0       24.8125
#    39.7363     0.0       39.7363        0.0       39.7363     0.0
#     0.0       24.8125     0.0     …  -167.728      0.0       24.8125
#    39.7363     0.0       39.7363        0.0     -436.493      0.0
#     0.0       24.8125     0.0          24.8125     0.0     -360.269

# %%
w = 1350:1700

gtilde = [Gtilde!(ww, (495, 938), -2, 0.02, [1,1,1]) for ww in w]
scatter(w, gtilde)
plot!(ylim = (-100, 100))
