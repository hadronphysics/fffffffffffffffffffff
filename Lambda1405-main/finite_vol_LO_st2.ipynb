# %%
using PyPlot
using Roots
using NLsolve
using DataFrames
using CSV
using PyCall

# %%
opt = pyimport("scipy.optimize")
# Out:
# PyObject <module 'scipy.optimize' from '/opt/miniconda3/lib/python3.10/site-packages/scipy/optimize/__init__.py'>

# %%
using IMinuit

# %%
PyPlot.svg(false)
# Out:
# false

# %%
include("./src/lattice_data.jl")
include("./src/latt_para.jl")
include("./src/tmat_finite_vol.jl")
include("./src/tmat_finite_vol_nlo.jl")
# Out:
# pole_finite_vol_nlo! (generic function with 1 method)

# %%
latt_para = lattice_params()
# Out:
# Dict{Symbol, Any} with 5 entries:
#   :m_meson    => (203.655, 486.366)
#   :threshold  => [1397.59, 1466.14, 1683.94, 1781.53]
#   :decons_vec => [93.1531, 108.23, 119.217, 108.23]
#   :L          => 0.0205243
#   :mch        => [(203.655, 1193.94), (486.366, 979.777), (551.1, 1132.84), (48…

# %% [markdown]
# # Energy level

# %% [markdown]
# At leading order s wave, we only consider two-energy level. For higher energy levels, we should include p wave.

# %%
fig, ax = PyPlot.subplots()
plot_latt_ener_2level!(ax, _2lv, _2lv_err, latt_para[:threshold] )
ax.grid()
gcf()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
function cost_fun!(latt_pole, latt_pole_err, params, Nv, fitted_para; dof=2,  fix_f=false)
    para = copy(params)
    if fix_f == true
        a1, a2, f, fπ = fitted_para
        
        para[:decons_vec] = [fπ fπ*f; fπ*f fπ]
    else
        a1, a2 = fitted_para
    end

    dd = 0e0
    len = 0e0
    for (pole, pole_err, N) in zip(latt_pole, latt_pole_err, Nv)
        p = []
        df1 = bisection_internal_sol!(x -> tdet_finite_vol_params!(x, para, [a1, a2], N), 1350, 1400, 1)
        df2 = bisection_internal_sol!(x -> tdet_finite_vol_params!(x, para, [a1, a2], N), 1420, 1468, 1)
        x10 = df1.x0
        x20 = df2.x0

        if length(x10) == 1
            append!(p, x10)
        else
            append!(p, pole_finite_vol!(1380, para, [a1, a2], N))
        end
        
        if length(x20) == 1
            append!(p, x20)
        else
            append!(p, pole_finite_vol!(1466, para, [a1, a2], N) )
        end
        
        d = (pole - p) ./ pole_err
        dd += d' * d
        len += length(pole)
    end
    return dd / (len - dof)
end

Nv = [[0,0,0], [0,0,1],[0,1,1],[1,1,1]]

#=
function makefit_finite_lo!(costfun, init_para)
    m = Minuit(costfun, init_para, limit_x0=(-5, -0.1), limit_x1=(-5, -0.1))
    m.strategy = 2
    migrad(m)
    migrad(m)
end
=#
#m = makefit_finite_lo!(f -> cost_fun!(_2lv, _2lv_err, params, Nv, f), [-1.6325762046840782, -1.7138485812778343])
# Out:
# makefit_finite_lo! (generic function with 1 method)

# %%
params = copy(latt_para)
f = 1.1999999988821624
fπ = 93

#params[:decons_vec] = [fπ fπ*f; fπ*f fπ]#[92.4, 92.4, 92.4, 92.4] .* 1.2
params[:decons_vec] = [fπ, 108e0]
# Out:
# 2-element Vector{Float64}:
#   93.0
#  108.0

# %%
#a_fit = [m.values...]
 a_fit = [-1.6325807018101615, -1.7138494070912544]
# Out:
# 2-element Vector{Float64}:
#  -1.6325807018101615
#  -1.7138494070912544

# %%
w = 1300:1:1466
fig, ax = PyPlot.subplots(1, 4, figsize=(14, 3.5), tight_layout=true)
title = [L"$[0,0,0]$", L"$[0,0,1]$", L"$[0,1,1]$", L"$[1,1,1]$"]
for (i, G) in enumerate([[0,0,0], [0,0,1],[0,1,1],[1,1,1]] )
    ax[i].set_title(title[i])
    @time plot_tdet_finite_vol!(ax[i], w, params, a_fit, G)
end
gcf()
# Out:
#   1.360490 seconds (14.23 M allocations: 589.139 MiB, 6.21% gc time, 83.59% compilation time)
#   0.466318 seconds (23.83 M allocations: 671.494 MiB, 13.63% gc time, 4.87% compilation time)
#   0.436814 seconds (23.82 M allocations: 667.350 MiB, 12.85% gc time)
#   0.437417 seconds (23.93 M allocations: 669.711 MiB, 12.29% gc time)
# Figure(PyObject <Figure size 1400x350 with 4 Axes>)

# %%
@time bisection_internal_sol!(x -> tdet_finite_vol_params!(x, params, a_fit, [0, 1, 1]), 1350, 1466, 1)
# Out:
#   4.310398 seconds (57.89 M allocations: 1.977 GiB, 8.09% gc time, 78.53% compilation time)
# 2×3 DataFrame
#  Row │ bis_inter     bis_x0   x0
#      │ Any           Any      Any
# ─────┼────────────────────────────────
#    1 │ (1385, 1386)  1385.32  1385.32
#    2 │ (1454, 1455)  1454.62  1454.62

# %%
function pole_finite_LO_2lv_bisection!(params, a, Nv)
    p = DataFrame([])
    columns = ["[0, 0, 0]", "[0, 0, 1]", "[0,1,1]", "[1,1,1]"]

    for (i, N) in enumerate(Nv)
        df = bisection_internal_sol!(x -> tdet_finite_vol_params!(x, params, a, N), 1350, 1470, 1)
        x0 = df.x0
        p[!, columns[i] ] = x0
    end
    #pp = DataFrame(p, ["[0,0,0]", "[0,0,1]", "[0,1,1]", "[1,1,1]"])
    return p
end
df = pole_finite_LO_2lv_bisection!(params, a_fit, Nv)
pole = [df[1:2, i] for i in 1:4]
df
# Out:
# 2×4 DataFrame
#  Row │ [0, 0, 0]  [0, 0, 1]  [0,1,1]  [1,1,1]
#      │ Any        Any        Any      Any
# ─────┼────────────────────────────────────────
#    1 │ 1379.89    1383.65    1385.32  1386.8
#    2 │ 1453.41    1462.04    1454.62  1447.35

# %%
fig, ax = PyPlot.subplots()
plot_theory_ener_2level!(ax, pole)
plot_latt_ener_2level!(ax, _2lv, _2lv_err, latt_para[:threshold] )
ax.grid()
fig.savefig("./figure/two_energy_level_fitted.pdf")
gcf()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # 4 energy levels

# %%
fig, ax = PyPlot.subplots()
#plot_theory_ener_2level!(ax, pole)
plot_latt_ener!(ax, latt_pole, latt_pole_err, latt_para[:threshold] )
ax.grid()
gcf()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# We try to fit to all energy levels.

# %%
function cost_fun!(latt_pole, latt_pole_err, params, Nv, fitted_para; dof=2,  fix_f=true)
    para = copy(params)
    if fix_f == false
        a1, a2, fπ, f = fitted_para
        
        para[:decons_vec] = [fπ fπ*f; fπ*f fπ]
    else
        a1, a2 = fitted_para
    end

    dd = 0e0
    len = 0e0
    for (pole, pole_err, N) in zip(latt_pole, latt_pole_err, Nv)
        x0 = N == [0, 0, 1] || N == [1, 1, 1] ? bisection_pole_finite_vol!(params, [a1, a2], N) : [pole_finite_vol!(init_x, para, [a1, a2], N) for init_x in pole]
        d = (pole - x0) ./ pole_err
        dd += d' * d
        len += length(pole)
    end
    return dd / (len - dof)
end

Nv = [[0,0,0], [0,0,1],[0,1,1],[1,1,1]]

function makefit_finite_lo1!(costfun, init_para)
    m = Minuit(costfun, init_para, fix_x1=true, fix_x2=true, limit_x3=(1, 1.3) )
    m.strategy = 2
    migrad(m)
    migrad(m)
end

function makefit_finite_lo!(costfun, init_para)
    m = Minuit(costfun, init_para, fix_x1=true)
    m.strategy = 2
    migrad(m)
    migrad(m)
end
#-1.4606403424973218, -2.0
@time cost_fun!(latt_pole, latt_pole_err, params, Nv, [-1.85226, -2.0]; dof=2,  fix_f=true)
# Out:
#  14.191757 seconds (423.24 M allocations: 11.605 GiB, 12.77% gc time, 0.29% compilation time)
# 1.424032453016493

# %%
m1 = makefit_finite_lo1!(f -> cost_fun!(latt_pole, latt_pole_err, params, Nv, f, dof=4), [-1.4606403424973218, -2., 92.4, 1.123])

# %%
function one_sigma_err_band!(costfun)
    a2 = -2.5:0.01:-1.84
    df = DataFrame([[] []], [:a1, :a2] )
    CSV.write("./out/one_sigma_LO.csv", df)
    
    for a in a2
        bounds = [(nothing, nothing), (a-1e-8, a+1e-8)]
        sol = opt.minimize(f -> costfun(latt_pole, latt_pole_err, params, Nv, f), [-1.4606403424973218, a], bounds=bounds, tol=1e-6, options=Dict("maxiter" => 100))
        if sol["fun"] < 2.5
            df = DataFrame(x0=[sol["x"][1]], x2=[sol.["x"][2]], :auto)
            CSV.write("./out/one_sigma_LO.csv", df, append=true)
        else
            continue
        end
    end
end
one_sigma_err_band!(cost_fun!)
# Out:
# type Dict has no field success
#
#
#
# Stacktrace:
#
#  [1] getproperty(x::Dict{Any, Any}, f::Symbol)
#
#    @ Base ./Base.jl:37
#
#  [2] one_sigma_err_band!(costfun::typeof(cost_fun!))
#
#    @ Main ~/Documents/works_in_ific/lam1405_10_08_2023/energy_level_julia/finite_vol_LO.ipynb:9
#
#  [3] top-level scope
#
#    @ ~/Documents/works_in_ific/lam1405_10_08_2023/energy_level_julia/finite_vol_LO.ipynb:17

# %%
bounds = [(nothing, nothing), (-2-1e-8, -2+1e-8)]
res = opt.minimize(f -> cost_fun!(latt_pole, latt_pole_err, params, Nv, f), [-1.4606403424973218, -2.2], bounds=bounds, tol=1e-6, options=Dict("maxiter" => 10))
# Out:
# Dict{Any, Any} with 10 entries:
#   "hess_inv" => PyObject <2x2 LbfgsInvHessProduct with dtype=float64>
#   "fun"      => 1.37207
#   "nfev"     => 60
#   "nit"      => 4
#   "status"   => 0
#   "message"  => "CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH"
#   "x"        => [-1.65226, -2.0]
#   "jac"      => [0.0651922, -1.849]
#   "success"  => true
#   "njev"     => 20

# %%
res["x"]
# Out:
# 2-element Vector{Float64}:
#  -1.6522609178881171
#  -1.9999999922291054

# %%
m = makefit_finite_lo!(f -> cost_fun!(latt_pole, latt_pole_err, params, Nv, f), [-1.4606403424973218, -2.2])
# Out:
# PyObject <FMin algorithm='Migrad' edm=5.865029488471818e-08 edm_goal=0.0002 errordef=1.0 fval=1.6032601770564494 has_accurate_covar=True has_covariance=True has_made_posdef_covar=False has_parameters_at_limit=False has_posdef_covar=True has_reached_call_limit=False has_valid_parameters=True hesse_failed=False is_above_max_edm=False is_valid=True nfcn=47 ngrad=0 reduced_chi2=nan time=-41.29388441600895>
# (Param(number=0, name='x0', value=-1.316071079497127, error=1.2158015896063252, merror=None, is_const=False, is_fixed=False, lower_limit=None, upper_limit=None), Param(number=1, name='x1', value=-2.2, error=0.022000000000000002, merror=None, is_const=False, is_fixed=True, lower_limit=None, upper_limit=None))
# [[1.47817351 0.        ]
#  [0.         0.        ]]

# %%
[m.values...]
# Out:
# 2-element Vector{Float64}:
#  -1.316071079497127
#  -2.2

# %%
w = 1100:1:1700
fig, ax = PyPlot.subplots(1, 4, figsize=(14, 3.5), tight_layout=true)
title = [L"$[0,0,0]$", L"$[0,0,1]$", L"$[0,1,1]$", L"$[1,1,1]$"]
for (i, G) in enumerate([[0,0,0], [0,0,1],[0,1,1],[1,1,1]] )
    ax[i].set_title(title[i])
    @time plot_tdet_finite_vol!(ax[i], w, params, [m.values...], G)
end
gcf()
# Out:
#   0.782590 seconds (37.46 M allocations: 1.191 GiB, 21.43% gc time)
#   1.685353 seconds (85.48 M allocations: 2.340 GiB, 21.22% gc time)
#   1.701546 seconds (85.72 M allocations: 2.345 GiB, 21.29% gc time)
#   1.700700 seconds (86.10 M allocations: 2.354 GiB, 21.24% gc time)
# Figure(PyObject <Figure size 1400x350 with 4 Axes>)

# %%
df2 = pole_finite_vol_all_boost!(latt_pole, params, [m.values...], Nv)
pole2 = [df2[!, i] for i in 1:4]
df2
# Out:
# 4×4 DataFrame
#  Row │ [0, 0, 0]  [0, 0, 1]  [0,1,1]  [1,1,1]
#      │ Float64    Float64    Float64  Any
# ─────┼────────────────────────────────────────
#    1 │   1381.59    1385.5   1386.98  1387.42
#    2 │   1448.54    1452.54  1436.88  1426.45
#    3 │   1531.64    1504.46  1502.8   1502.92
#    4 │   1553.58    1515.17   NaN     1519.01

# %%
fig, ax = PyPlot.subplots()
plot_latt_ener!(ax, latt_pole, latt_pole_err, latt_para[:threshold] )
plot_theory_ener!(ax, pole2)
gcf()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
